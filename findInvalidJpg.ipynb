# %%
import sys, os
from PIL import Image

for klasse in os.listdir('Prisioners'):
    classdir=os.path.join('Prisioners',klasse)
    for infile in os.listdir(classdir):
        with Image.open(os.path.join(classdir,infile)) as im:
            print(infile, im.format, f"{im.size}x{im.mode}")
# Out:
# A10506.jpg JPEG (300, 297)xRGB
# A25193.jpg JPEG (300, 297)xRGB
# A50005.jpg JPEG (300, 297)xRGB
# A61191.jpg JPEG (300, 300)xRGB
# A61589.jpg JPEG (300, 297)xRGB
# A64002.jpg JPEG (300, 300)xRGB
# A67856.jpg JPEG (300, 300)xRGB
# A67942.jpg JPEG (300, 300)xRGB
# A70206.jpg JPEG (300, 300)xRGB
# A70223.jpg JPEG (300, 297)xRGB
# A72922.jpg JPEG (300, 300)xRGB
# A78306.jpg JPEG (300, 300)xRGB
# A78639.jpg JPEG (300, 297)xRGB
# A80254.jpg JPEG (300, 297)xRGB
# A82768.jpg JPEG (300, 300)xRGB
# A83069.jpg JPEG (300, 297)xRGB
# A83101.jpg JPEG (300, 297)xRGB
# A83622.jpg JPEG (300, 297)xRGB
# A90145.jpg JPEG (300, 297)xRGB
# A90268.jpg JPEG (300, 297)xRGB
# A91082.jpg JPEG (300, 297)xRGB
# A91478.jpg JPEG (300, 297)xRGB
# A91885.jpg JPEG (300, 300)xRGB
# A93421.jpg JPEG (300, 300)xRGB
# A93480.jpg JPEG (300, 300)xRGB
# A97536.jpg JPEG (300, 300)xRGB
# B01291.jpg JPEG (300, 297)xRGB
# B02604.jpg JPEG (300, 300)xRGB
# B02669.jpg JPEG (300, 297)xRGB
# B04130.jpg JPEG (300, 297)xRGB
# ...
